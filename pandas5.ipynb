# %% [markdown]
# <a href="https://colab.research.google.com/github/moshehaimlevi/numpy.repo/blob/main/pandas5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##################### Q1 #####################
import numpy as np
from IPython.display import display
import pandas as pd
df = pd.DataFrame({'A':[None, 2, 3, None, 5], 'B':[10, None, None, 40, 50], 'C':[100, None, 300, 400,
None]})
display(df)
# Out:
#      A     B      C
# 0  NaN  10.0  100.0
# 1  2.0   NaN    NaN
# 2  3.0   NaN  300.0
# 3  NaN  40.0  400.0
# 4  5.0  50.0    NaN

# %%
##################### SECTION A #####################
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
##################### SECTION B #####################

df.dropna(subset=['A', 'B', 'C'])
# Out:
# Empty DataFrame
# Columns: [A, B, C]
# Index: []

# %%
##################### SECTION C #####################
df.dropna(subset=['A', 'C'])
# Out:
#      A   B      C
# 2  3.0 NaN  300.0

# %%
##################### SECTION D #####################
df.fillna(25)
# Out:
#       A     B      C
# 0  25.0  10.0  100.0
# 1   2.0  25.0   25.0
# 2   3.0  25.0  300.0
# 3  25.0  40.0  400.0
# 4   5.0  50.0   25.0

# %%
##################### SECTION E #####################
df['B'].fillna(20)
# Out:
# 0    10.0
# 1    20.0
# 2    20.0
# 3    40.0
# 4    50.0
# Name: B, dtype: float64
